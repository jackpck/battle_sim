# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
for i in [1,5,10,15,20]:
    df = pd.read_csv('./data/reserve_%i.csv'%i, index_col=0)
    plt.plot(df.health1, df.favor, label=i)
plt.legend(loc='best')
plt.show()
